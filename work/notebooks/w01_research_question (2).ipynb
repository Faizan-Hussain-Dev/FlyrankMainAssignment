# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Faizan-Hussain-Dev/FlyrankMainAssignment/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I am declaring a freestyle lane focused on predicting Content Decay-specifically, identifying which pages are most likely to experience a traffic drop in the next 30 days. Approaching this problem as "traffic churn" leverages established pandas and machine learning workflows from previous full-stack churn prediction projects. Predicting URL decline transforms a reactive SEO problem into a proactive, data-driven workflow.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Decision**: Which existing web pages should a content optimization team prioritize for a comprehensive refresh?
#
# **Action**: An SEO manager assigns an editorial team to update the identified pages with fresh information and optimized formatting.
#
# **Cost of a Wrong Call**: Flagging a healthy page (false positive) wastes the editorial budget on unnecessary updates. Missing a declining page (false negative) results in a sustained loss of organic traffic and potential conversions.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
hf_token = "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"

dataset_url = "hf://datasets/FlyRank/internship-warehouse/fact_content_daily_performance_sample.parquet"

# 3. Load the dataset into a Pandas DataFrame
print("Loading sample dataset...")
df = pd.read_parquet(dataset_url, storage_options={"token": hf_token})

# 4. Extract 2-3 real numbers for the assignment
total_rows = len(df)
# We will use the columns available in standard daily fact tables
unique_content_urls = df['content_hash'].nunique() if 'content_hash' in df.columns else "Multiple"

print(f"Total performance records in sample: {total_rows:,}")

# Check if unique_content_urls is an integer before formatting
if isinstance(unique_content_urls, int):
    print(f"Unique content pieces analyzed: {unique_content_urls:,}")
else:
    print(f"Unique content pieces analyzed: {unique_content_urls}")
# Out:
# Loading sample dataset...
# Total performance records in sample: 11,694,072
# Unique content pieces analyzed: Multiple

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This model will deliver measured, directional insights acting strictly as a decision-support tool. It observes historical patterns correlated with traffic drops. It will never claim to "predict Google's algorithm," reverse-engineer search ranking factors, or provide causal proof that a specific element caused a ranking penalty.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
